# %%
import pandas as pd

# %%
df = pd.read_excel('./../DataFiles/Adam.xlsx')

# %%
df.head()
# Out:
#   Classification   sum  CCTV installed before 2016  2016  2017  2018  2019  \
# 0      Jongno-gu  2290                         230   100   140   140    66
# 1        Zhonggu  3021                         376   220   366   381   155
# 2     Yongsan-gu  3300                         106   295   491   147   335
# 3   Seongdong-gu  4514                         542   278   939   457   640
# 4    Gwangjin-gu  4156                         403    42   666   460   712
#
#    2020  2021  2022  2023  2024
# 0   233    85   219   919   158
# 1   357   414   137   135   480
# 2   473   486   413   492    62
# 3   483   366   233   471   105
# 4   191   740   273   340   329

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
years = df['Classification']
values = df['2016']

# %%
x = np.arange(26)

# %%
# complete your work
plt.figure(figsize=(20, 10))
plt.bar(x, values,  color=['r','g','b'], align='edge', width=0.5)
plt.xticks(x, years, rotation='vertical')
plt.xlabel('Districts', loc='right')
plt.ylabel('CCTVs', loc='top')

plt.show()
