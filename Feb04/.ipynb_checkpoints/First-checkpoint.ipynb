# %%
df
# Out:
#      Classification     sum  CCTV installed before 2016  2016   2017   2018  \
# 0         Jongno-gu    2290                         230   100    140    140
# 1           Zhonggu    3021                         376   220    366    381
# 2        Yongsan-gu    3300                         106   295    491    147
# 3      Seongdong-gu    4514                         542   278    939    457
# 4       Gwangjin-gu    4156                         403    42    666    460
# 5     Dongdaemun-gu    3446                           0   657    670    199
# 6       Jungnang-gu    4512                         479   153    170    215
# 7       Seongbuk-gu    4543                         320   380    382    758
# 8        Gangbuk-gu    3584                          44   196      1    352
# 9         Dobong-gu    2378                           3    68     80    152
# 10         Nowon-gu    3111                         592   304    160    207
# ...

# %%
# import pandas and read your csv file with it
import pandas as pd
df =

# %%
# store the first row of the table
temp = df.loc[0]
# shif up the values in the table by one row
for each in range(len(df)-2):
    df.loc[each] = df.loc[each+1]
# restore the original first row values of the table at the end of the table
df.loc[len(df)-1] = temp

# %%
df_shifted = df.shift(-1)
df_shifted.iloc[-1] = df.iloc[0]
df = df_shifted

# %%
df
# Out:
#       순번    구분       총 계  2016년 이전 설치된 CCTV   2016년    2017년    2018년  \
# 0    1.0   종로구    2290.0              230.0   100.0    140.0    140.0
# 1    2.0   중 구    3021.0              376.0   220.0    366.0    381.0
# 2    3.0   용산구    3300.0              106.0   295.0    491.0    147.0
# 3    4.0   성동구    4514.0              542.0   278.0    939.0    457.0
# 4    5.0   광진구    4156.0              403.0    42.0    666.0    460.0
# 5    6.0  동대문구    3446.0                0.0   657.0    670.0    199.0
# 6    7.0   중랑구    4512.0              479.0   153.0    170.0    215.0
# 7    8.0   성북구    4543.0              320.0   380.0    382.0    758.0
# 8    9.0   강북구    3584.0               44.0   196.0      1.0    352.0
# 9   10.0   도봉구    2378.0                3.0    68.0     80.0    152.0
# 10  11.0   노원구    3111.0              592.0   304.0    160.0    207.0
# 11  12.0   은평구    5027.0              841.0   493.0    361.0    579.0
# ...

# %%
# translate all elements in the table into English
from translate import Translator
translator = Translator(to_lang="en", from_lang="ko")

# %%
# collect the english columns 
eng_columns = list()
for each in df.columns:
    eng_columns.append(translator.translate(each))

# %%
df = df.rename(columns=dict(zip(df.columns, eng_columns)))

# %%
df.head()
# Out:
#    Number Classification     sum  CCTV installed before 2016   2016   2017  \
# 0     1.0            종로구  2290.0                       230.0  100.0  140.0
# 1     2.0            중 구  3021.0                       376.0  220.0  366.0
# 2     3.0            용산구  3300.0                       106.0  295.0  491.0
# 3     4.0            성동구  4514.0                       542.0  278.0  939.0
# 4     5.0            광진구  4156.0                       403.0   42.0  666.0
#
#     2018   2019   2020   2021   2022   2023   2024
# 0  140.0   66.0  233.0   85.0  219.0  919.0  158.0
# 1  381.0  155.0  357.0  414.0  137.0  135.0  480.0
# 2  147.0  335.0  473.0  486.0  413.0  492.0   62.0
# 3  457.0  640.0  483.0  366.0  233.0  471.0  105.0
# 4  460.0  712.0  191.0  740.0  273.0  340.0  329.0

# %%
# where 1 is the axis number (0 for rows and 1 for columns.)
df =

# %%
df
# Out:
#    Classification       sum  CCTV installed before 2016    2016     2017  \
# 0             종로구    2290.0                       230.0   100.0    140.0
# 1             중 구    3021.0                       376.0   220.0    366.0
# 2             용산구    3300.0                       106.0   295.0    491.0
# 3             성동구    4514.0                       542.0   278.0    939.0
# 4             광진구    4156.0                       403.0    42.0    666.0
# 5            동대문구    3446.0                         0.0   657.0    670.0
# 6             중랑구    4512.0                       479.0   153.0    170.0
# 7             성북구    4543.0                       320.0   380.0    382.0
# 8             강북구    3584.0                        44.0   196.0      1.0
# 9             도봉구    2378.0                         3.0    68.0     80.0
# 10            노원구    3111.0                       592.0   304.0    160.0
# 11            은평구    5027.0                       841.0   493.0    361.0
# ...

# %%
# change all values as int
for each in df.columns[1:]:

# %%
df
# Out:
#    Classification     sum  CCTV installed before 2016  2016   2017   2018  \
# 0             종로구    2290                         230   100    140    140
# 1             중 구    3021                         376   220    366    381
# 2             용산구    3300                         106   295    491    147
# 3             성동구    4514                         542   278    939    457
# 4             광진구    4156                         403    42    666    460
# 5            동대문구    3446                           0   657    670    199
# 6             중랑구    4512                         479   153    170    215
# 7             성북구    4543                         320   380    382    758
# 8             강북구    3584                          44   196      1    352
# 9             도봉구    2378                           3    68     80    152
# 10            노원구    3111                         592   304    160    207
# 11            은평구    5027                         841   493    361    579
# ...

# %%
# collect the english values
eng_values = list()
for each in df.Classification:

# %%
eng_values
# Out:
# ['Jongno-gu',
#  'Zhonggu',
#  'Yongsan-gu',
#  'Seongdong-gu',
#  'Gwangjin-gu',
#  'Dongdaemun-gu',
#  'Jungnang-gu',
#  'Seongbuk-gu',
#  'Gangbuk-gu',
#  'Dobong-gu',
#  'Nowon-gu',
#  'Eunpyeong-gu',
#  'Seodaemun-gu',
#  'Mapo-gu',
#  'Yangcheon-gu',
#  'Gangseo-gu',
#  'Guro-gu',
#  'Geumcheon-gu',
#  'Yeongdeungpo-gu',
#  'Dongjak-gu',
#  'Gwanak-gu',
#  'Seocho-gu',
#  'Gangnam-gu',
#  'Songpa-gu',
#  'Gangdong-gu',
#  'Total']

# %%
df['Classification'] = df['Classification'].map(dict(zip(df.Classification, eng_values)))

# %%
df
# Out:
#      Classification     sum  CCTV installed before 2016  2016   2017   2018  \
# 0         Jongno-gu    2290                         230   100    140    140
# 1           Zhonggu    3021                         376   220    366    381
# 2        Yongsan-gu    3300                         106   295    491    147
# 3      Seongdong-gu    4514                         542   278    939    457
# 4       Gwangjin-gu    4156                         403    42    666    460
# 5     Dongdaemun-gu    3446                           0   657    670    199
# 6       Jungnang-gu    4512                         479   153    170    215
# 7       Seongbuk-gu    4543                         320   380    382    758
# 8        Gangbuk-gu    3584                          44   196      1    352
# 9         Dobong-gu    2378                           3    68     80    152
# 10         Nowon-gu    3111                         592   304    160    207
# ...
