# %%
# ready to call a csv file
import csv

# %%
filteredData = list()

# %%
# open a csv file with python. 
cnt = 0
with open('./../DataFiles/CCTVs for all districts in Seoul until 20240630.csv', mode ='r')as file:
    csvFile = csv.reader(file)
    for lines in csvFile:
        cnt = cnt + 1
        if cnt not in [1, 2, 4]:
            filteredData.append(lines)
        print(lines)
# Out:
# ['', '', '', '', '', '', '', '', '', '', '', '', '', "(단위 : 대, '24.6.30.일 기준)", '', '', '', '', '', '', '', '', '', '', '', '']
# []
# ['순번', '구분', '총 계', '2016년 이전 설치된 CCTV ', '2016년', '2017년', '2018년', '2019년', '2020년', '2021년', '2022년', '2023년', '2024년']
# ['계', '102,380', '11,692', '8,225', '10,865', '10,652', '12,854', '11,838', '9,558', '9,218', '13,919', '3,559']
# ['1', '종로구', '2,290', '230', '100', '140', '140', '66', '233', '85', '219', '919', '158']
# ['2', '중 구', '3,021', '376', '220', '366', '381', '155', '357', '414', '137', '135', '480']
# ['3', '용산구', '3,300', '106', '295', '491', '147', '335', '473', '486', '413', '492', '62']
# ['4', '성동구', '4,514', '542', '278', '939', '457', '640', '483', '366', '233', '471', '105']
# ['5', '광진구', '4,156', '403', '42', '666', '460', '712', '191', '740', '273', '340', '329']
# ['6', '동대문구', '3,446', '0', '657', '670', '199', '215', '229', '226', '317', '755', '178']
# ...

# %%
filteredData
# Out:
# [['순번',
#   '구분',
#   '총 계',
#   '2016년 이전 설치된 CCTV ',
#   '2016년',
#   '2017년',
#   '2018년',
#   '2019년',
#   '2020년',
#   '2021년',
#   '2022년',
#   '2023년',
#   '2024년'],
#  ['1',
#   '종로구',
#   '2,290',
#   '230',
#   '100',
#   '140',
#   '140',
#   '66',
#   '233',
#   '85',
#   '219',
#   '919',
#   '158'],
#  ['2',
#   '중 구',
#   '3,021',
#   '376',
#   '220',
#   '366',
#   '381',
#   '155',
#   '357',
#   '414',
#   '137',
#   '135',
#   '480'],
#  ['3',
#   '용산구',
#   '3,300',
#   '106',
#   '295',
#   '491',
#   '147',
#   '335',
#   '473',
#   '486',
#   '413',
#   '492',
#   '62'],
#  ['4',
#   '성동구',
#   '4,514',
#   '542',
#   '278',
#   '939',
#   '457',
#   '640',
#   '483',
#   '366',
#   '233',
#   '471',
#   '105'],
#  ['5',
#   '광진구',
#   '4,156',
#   '403',
#   '42',
#   '666',
#   '460',
#   '712',
#   '191',
#   '740',
#   '273',
#   '340',
#   '329'],
#  ['6',
#   '동대문구',
#   '3,446',
#   '0',
#   '657',
#   '670',
#   '199',
#   '215',
#   '229',
#   '226',
# ...

# %%
# Please show your work in order to provide a result below

# %%
districts
# Out:
# ['종로구',
#  '중 구',
#  '용산구',
#  '성동구',
#  '광진구',
#  '동대문구',
#  '중랑구',
#  '성북구',
#  '강북구',
#  '도봉구',
#  '노원구',
#  '은평구',
#  '서대문구',
#  '마포구',
#  '양천구',
#  '강서구',
#  '구로구',
#  '금천구',
#  '영등포구',
#  '동작구',
#  '관악구',
#  '서초구',
#  '강남구',
#  '송파구',
#  '강동구']

# %%
len(districts)
# Out:
# 25
